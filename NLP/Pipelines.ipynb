# %%
from transformers import pipeline

# %% [markdown]
# ### Sentiment Analysis

# %%
sentiment = pipeline("sentiment-analysis")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
print(sentiment("I love building AI agents"))
print(sentiment("Model is not good"))
# Out:
# [{'label': 'POSITIVE', 'score': 0.9990443587303162}]
# [{'label': 'NEGATIVE', 'score': 0.9997842907905579}]

# %% [markdown]
# ### Named entity recognition

# %%
ner = pipeline("ner", aggregation_strategy="simple")
# Out:
# [transformers] No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.weight | UNEXPECTED |  |
# bert.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
print(ner("My name is Hetvi and I study at LJ University in Gujarat"))
# Out:
# [{'entity_group': 'PER', 'score': np.float32(0.9450411), 'word': 'Hetvi', 'start': 11, 'end': 16}, {'entity_group': 'ORG', 'score': np.float32(0.99438477), 'word': 'LJ University', 'start': 32, 'end': 45}, {'entity_group': 'LOC', 'score': np.float32(0.9975949), 'word': 'Gujarat', 'start': 49, 'end': 56}]

# %% [markdown]
# ### Text generation

# %%
generator = pipeline("text-generation", model="gpt2")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
result = generator("AI agents is", max_length=50)
print(result[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# AI agents is not intended to be the sole instrument of an agent's control over an individual, but rather to be a means to a specific end. One reason why the idea of a state in which people are free to decide for themselves what they want to be is to make sure all citizens are free to choose what they want to be.
#
# The "liberal" version of the concept of government is to allow for a degree of freedom in order to help create the conditions for the future:
#
# ...

# %% [markdown]
# ### Zero shot classification

# %%
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
print(classifier(
    "I love watching cricket and also love politics",
    candidate_labels=["coding", "cooking", "sports", "politics"]
))
# Out:
# {'sequence': 'I love watching cricket and also love politics', 'labels': ['politics', 'sports', 'cooking', 'coding'], 'scores': [0.517833948135376, 0.4770278036594391, 0.003231380833312869, 0.001906828605569899]}
